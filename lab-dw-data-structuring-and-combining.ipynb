# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd

# %%
url1="https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv"
url2="https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv"
url3="https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv"
df1 = pd.read_csv(url1)
df2 = pd.read_csv(url2)
df3 = pd.read_csv(url3)

# %% [markdown]
# Customer,ST,GENDER,Education,Customer Lifetime Value,Income,Monthly Premium Auto,Number of Open Complaints,Policy Type,Vehicle Class,Total Claim Amount
#
# Customer,ST,GENDER,Education,Customer Lifetime Value,Income,Monthly Premium Auto,Number of Open Complaints,Total Claim Amount,Policy Type,Vehicle Class
#
# Customer,State,Customer Lifetime Value,Education,Gender,Income,Monthly Premium Auto,Number of Open Complaints,Policy Type,Total Claim Amount,Vehicle Class

# %%
df1.columns =df1.columns.str.strip().str.lower().str.replace(" ","_")
df2.columns =df2.columns.str.strip().str.lower().str.replace(" ","_")
df3.columns =df3.columns.str.strip().str.lower().str.replace(" ","_")

# %%
df1.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'total_claim_amount', 'policy_type', 'vehicle_class'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'education', 'gender',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %%
df1=df1.rename(columns={'st': 'state'})

# %%
df2=df2.rename(columns={'st': 'state'})

# %%
df=pd.concat([df1, df2, df3], axis=0)
df.head()
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
df["state"].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', nan],
#       dtype=object)

# %%
df['state'] =df['state'].apply(lambda x:"Arizona" if x=="AZ" else x)

# %%
df['state'] =df['state'].apply(lambda x:"Washington" if x=="WA" else x)

# %%
df['state'] =df['state'].apply(lambda x:"California" if x=="Cali" else x)

# %%
df["gender"].unique()
# Out:
# array([nan, 'F', 'M'], dtype=object)

# %%
gender_mapping = {'male': 'M', 'female': 'F','Femal':'F', 'M':'M','F':'F'}
#gender_mapping = {'male': 'M', 'female': 'F','Femal':'F'}
df['gender']= df['gender'].map(gender_mapping)
df.gender.value_counts(dropna=False)
# Out:
# gender
# F      4607
# M      4368
# NaN    3099
# Name: count, dtype: int64

# %%
df["education"].unique()
# Out:
# array(['Master', 'Bachelor', 'High School or Below', 'College', 'Doctor',
#        nan], dtype=object)

# %%
df['education'] =df['education'].apply(lambda x:"Bachelor" if x=="Bachelors" else x)

# %%
df["customer_lifetime_value"].unique()
# Out:
# array([nan, '697953.59%', '1288743.17%', ..., 8163.890428, 7524.442436,
#        2611.836866], shape=(8212,), dtype=object)

# %%
df['customer_lifetime_value'] = df['customer_lifetime_value'].str.replace('%', '')
df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# ...

# %%
df["customer_lifetime_value"].map(float)
# Out:
# 0              NaN
# 1        697953.59
# 2       1288743.17
# 3        764586.18
# 4        536307.65
#            ...
# 7065           NaN
# 7066           NaN
# 7067           NaN
# 7068           NaN
# 7069           NaN
# Name: customer_lifetime_value, Length: 12074, dtype: float64

# %%
df["income"].unique()
# Out:
# array([    0., 48767., 36357., ..., 66367., 71941., 21941.], shape=(5656,))

# %%
df["monthly_premium_auto"].unique()
# Out:
# array([ 1000.,    94.,   108.,   106.,    68.,    69.,    67.,   101.,
#           71.,    93.,   110.,    70.,    64.,    72.,    74.,    79.,
#           73.,    61.,   111.,    80.,    63.,   237.,    65.,   130.,
#           62.,   117.,    91.,    90.,    66.,    99.,   103., 35354.,
#          172.,    92.,   104.,   113.,   124.,   105.,   100.,   112.,
#           97.,    95.,   102.,    96.,   186.,    77.,    76.,   119.,
#           87.,   109.,   107.,    88.,    85.,  6464.,   133.,    86.,
#           78.,    89.,   192.,   118.,   140.,   127.,   126.,    82.,
#          115.,   217.,   114.,   138.,    81.,   255.,   150.,   123.,
#          116.,   190.,    98.,   159.,    84.,    83.,   152.,   136.,
#          245.,   135.,  1005.,   225.,   132.,   153.,   121.,   139.,
#          154.,   161.,   156.,   171.,   244.,   183.,   176.,   230.,
#          129.,   177.,   181.,   196.,   131.,   276.,   253.,   137.,
# ...

# %%
df["number_of_open_complaints"].unique()
# Out:
# array(['0', '2', '1', '3', '5', '4', nan], dtype=object)

# %%
df['number_of_open_complaints'] = df['number_of_open_complaints'].str.split('/').str[1]
df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# ...

# %%
df["policy_type"].unique()
# Out:
# array(['Personal Auto', 'Corporate Auto', 'Special Auto', nan],
#       dtype=object)

# %%
df["vehicle_class"].unique()
# Out:
# array(['Four-Door Car', 'Two-Door Car', 'SUV', 'Luxury', nan],
#       dtype=object)

# %%
df['vehicle_class'] =df['vehicle_class'].apply(lambda x:"Luxury" if x in["Sports Car","Luxury SUV","Luxury Car"] else x)

# %%
df["total_claim_amount"].unique()
# Out:
# array([   2.704934, 1131.464935,  566.472247, ...,  541.282007,
#         198.234764,  790.784983], shape=(5071,))

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# ...

# %%
df=df.dropna(how='all')

# %%
df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
url4="https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv"

df4= pd.read_csv(url4)

# %%
df4.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type', 'month'],
#       dtype='object')

# %%
df4 = df4.drop('unnamed:_0', axis=1)

# %%
df4=df4.dropna(how='all')

# %%
df4.drop_duplicates(inplace=True)

# %%
df4["state"].unique()
# Out:
# array(['Arizona', 'California', 'Washington', 'Oregon', 'Nevada'],
#       dtype=object)

# %%
df4["customer_lifetime_value"].unique()
# Out:
# array([ 4809.21696 ,  2228.525238, 14947.9173  , ...,  5259.444853,
#        23893.3041  , 11971.97765 ], shape=(8041,))

# %%
df4["education"].unique()
# Out:
# array(['College', 'Bachelor', 'High School or Below', 'Doctor', 'Master'],
#       dtype=object)

# %%
df4["gender"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df4["education"].unique()
# Out:
# array(['College', 'Bachelor', 'High School or Below', 'Doctor', 'Master'],
#       dtype=object)

# %%
df4["number_of_policies"].unique()
# Out:
# array([9, 1, 2, 7, 4, 3, 6, 8, 5])

# %%
df4["policy_type"].unique()
# Out:
# array(['Corporate Auto', 'Personal Auto', 'Special Auto'], dtype=object)

# %%
df4["policy"].unique()
# Out:
# array(['Corporate L3', 'Personal L3', 'Personal L2', 'Corporate L2',
#        'Personal L1', 'Special L1', 'Corporate L1', 'Special L3',
#        'Special L2'], dtype=object)

# %%
df4["renew_offer_type"].unique()
# Out:
# array(['Offer3', 'Offer4', 'Offer2', 'Offer1'], dtype=object)

# %%
df4["sales_channel"].unique()
# Out:
# array(['Agent', 'Call Center', 'Branch', 'Web'], dtype=object)

# %%
df4["total_claim_amount"].unique()
# Out:
# array([292.8     , 744.924331, 480.      , ..., 273.018929, 381.306996,
#        618.288849], shape=(5106,))

# %%
df4["vehicle_class"].unique()
# Out:
# array(['Four-Door Car', 'SUV', 'Two-Door Car', 'Luxury'], dtype=object)

# %%
df4['vehicle_class'] =df4['vehicle_class'].apply(lambda x:"Luxury" if x in["Sports Car","Luxury SUV","Luxury Car"] else x)

# %%
df4["vehicle_size"].unique()
# Out:
# array(['Medsize', 'Small', 'Large'], dtype=object)

# %%
df4["vehicle_type"].unique()
# Out:
# array(['A'], dtype=object)

# %%
df4["month"].unique()
# Out:
# array([2, 1])

# %%
df4["income"].unique()
# Out:
# array([48029,     0, 22139, ..., 61146, 39837, 64195], shape=(5694,))

# %%
df4["employmentstatus"].unique()
# Out:
# array(['Employed', 'Unemployed', 'Medical Leave', 'Disabled', 'Retired'],
#       dtype=object)

# %%
df4["effective_to_date"].unique()
# Out:
# array(['2011-02-18', '2011-01-18', '2011-02-10', '2011-01-11',
#        '2011-01-17', '2011-02-14', '2011-02-24', '2011-01-19',
#        '2011-01-04', '2011-01-02', '2011-02-07', '2011-01-31',
#        '2011-01-26', '2011-02-28', '2011-01-16', '2011-02-26',
#        '2011-02-23', '2011-01-15', '2011-02-02', '2011-02-15',
#        '2011-01-24', '2011-02-21', '2011-02-22', '2011-01-07',
#        '2011-01-28', '2011-02-08', '2011-02-12', '2011-02-20',
#        '2011-01-05', '2011-02-19', '2011-01-03', '2011-02-03',
#        '2011-01-22', '2011-01-23', '2011-02-05', '2011-02-13',
#        '2011-01-25', '2011-02-16', '2011-02-01', '2011-01-27',
#        '2011-01-12', '2011-01-20', '2011-02-06', '2011-02-11',
#        '2011-01-21', '2011-01-29', '2011-01-09', '2011-02-09',
#        '2011-02-27', '2011-01-01', '2011-02-17', '2011-02-25',
#        '2011-01-13', '2011-01-06', '2011-02-04', '2011-01-14',
#        '2011-01-10', '2011-01-08', '2011-01-30'], dtype=object)

# %%
df4["coverage"].unique()
# Out:
# array(['Basic', 'Extended', 'Premium'], dtype=object)

# %%
df4["response"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df4["monthly_premium_auto"].unique()
# Out:
# array([ 61,  64, 100,  97, 117,  63, 154,  85, 127,  62,  99,  69, 116,
#        114,  66,  73,  94, 104, 189,  74, 121, 110, 111,  72, 115, 159,
#        101,  65,  82,  71, 126,  68, 199,  96,  67, 125, 249, 105,  92,
#         78,  77,  79, 223, 242,  70, 102, 109, 107, 119, 194, 113, 106,
#        247,  80,  86,  81,  83, 122, 253, 196, 132, 139,  84, 130,  93,
#        103, 112, 222, 118,  88, 182, 283,  90, 128,  89, 235, 190,  76,
#         87, 133, 153, 129,  98, 148, 123,  91, 211, 131, 108, 187, 214,
#        181, 173, 252,  95, 124, 137, 145, 188, 143, 198, 138, 245, 195,
#        186, 170, 136, 161, 157, 141, 205, 271, 192, 142, 140, 134, 240,
#        185, 244, 210, 184, 202, 296, 213, 273, 219, 135, 169, 155, 225,
#        266, 215, 197, 256, 212, 158, 180, 166, 168, 183, 162, 191, 179,
#        150, 146, 276, 165, 239, 237, 193, 229, 274, 207, 295, 208, 172,
#        217, 206, 201, 171, 152, 156, 174, 238, 167, 151, 144, 163, 287,
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
#pivot_df = df.pivot_table(index='country', columns='year', values=['GDP'], aggfunc='sum')

pivot_df4 = df4.pivot_table(columns='sales_channel', values=['customer_lifetime_value'], aggfunc='sum').round(2)

# %%
pivot_df4
# Out:
#               customer_lifetime_value
# sales_channel                   Agent      Branch Call Center         Web
# state
# Arizona                    5586389.95  3891645.76  3102507.00  2279726.78
# California                11737509.30  8972387.87  5939474.76  4403790.83
# Nevada                     3289841.30  1980483.21  1614363.91  1105972.79
# Oregon                     8585034.66  6543171.94  4626754.38  3483902.92
# Washington                 2624095.76  2158169.97  1267331.00   845134.08

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
pivot_df5= df4.pivot_table(index='gender',columns='sales_channel', values=['customer_lifetime_value'], aggfunc='sum').round(2)
pivot_df5
# Out:
#               customer_lifetime_value
# sales_channel                   Agent       Branch Call Center         Web
# gender
# F                         15811204.87  11980249.97  8686720.71  6708560.70
# M                         16011666.09  11565608.77  7863710.34  5409966.69

# %%
pivot_df6= df4.pivot_table(index='education',columns='sales_channel', values=['customer_lifetime_value'], aggfunc='sum').round(2)
pivot_df6
# Out:
#                      customer_lifetime_value                          \
# sales_channel                          Agent      Branch Call Center
# education
# Bachelor                          9449429.79  6352351.33  5223441.28
# College                           8698261.67  7692892.11  4200913.47
# Doctor                            1113059.16   723866.51   697029.47
# High School or Below              9920928.21  6762578.20  5025408.15
# Master                            2641192.14  2014170.59  1403638.68
#
#
# sales_channel                Web
# education
# Bachelor              3419720.47
# College               3635411.73
# Doctor                 341733.73
# High School or Below  3685479.27
# Master                1036182.19

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
